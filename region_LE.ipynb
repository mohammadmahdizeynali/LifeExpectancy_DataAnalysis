# %% [markdown]
# # In the name of ALLAH

# %%
# import library that we need

import pandas as pd
import matplotlib.pyplot as plt

# %%
# import dataset

df = pd.read_csv("primary_dataset.csv")
df.head()
# Out:
#        Country Region  Year  Infant_deaths  Under_five_deaths  \
# 0  Afghanistan   Asia  2015           53.2               70.4
# 1  Afghanistan   Asia  2014           55.2               73.6
# 2  Afghanistan   Asia  2013           57.3               76.9
# 3  Afghanistan   Asia  2012           59.5               80.3
# 4  Afghanistan   Asia  2011           61.8               84.0
#
#    Adult_mortality  Alcohol_consumption  Hepatitis_B  Measles   BMI  ...  \
# 0          227.735                 0.00           65       42  23.3  ...
# 1          231.978                 0.01           62       44  23.2  ...
# 2          236.221                 0.01           64       38  23.0  ...
# 3          240.464                 0.01           67       33  22.9  ...
# 4          245.300                 0.01           68       31  22.8  ...
#
#    Diphtheria  Incidents_HIV  GDP_per_capita  Population_mln  \
# 0          65           0.03             556           34.41
# ...

# %%
df['Life_expectancy'].dtype
# Out:
# dtype('float64')

# %%
df_grouped_by_region = df.groupby('Region')['Life_expectancy'].mean().reset_index()
df_grouped_by_region = df_grouped_by_region.rename(columns={'Life_Expectancy': 'mean_life_expectancy'})
df_grouped_by_region.head()
# Out:
#                           Region  Life_expectancy
# 0                         Africa        57.847304
# 1                           Asia        69.454861
# 2  Central America and Caribbean        72.437500
# 3                 European Union        77.715046
# 4                    Middle East        73.975446

# %%
# Plotting the data on a bar plot
plt.figure(figsize=(12, 6))
plt.bar(df_grouped_by_region['Region'], df_grouped_by_region['Life_expectancy'], color='skyblue')
plt.xlabel('Region')
plt.ylabel('Mean Life Expectancy')
plt.title('Mean Life Expectancy by Region')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %%
df_grouped = df.groupby(['Region', 'Year'])['Life_expectancy'].mean().reset_index()
df_grouped.head(20)
# Out:
#     Region  Year  Life_expectancy
# 0   Africa  2000        54.137255
# 1   Africa  2001        54.358824
# 2   Africa  2002        54.594118
# 3   Africa  2003        54.964706
# 4   Africa  2004        55.450980
# 5   Africa  2005        55.956863
# 6   Africa  2006        56.570588
# 7   Africa  2007        57.243137
# 8   Africa  2008        57.933333
# 9   Africa  2009        58.627451
# 10  Africa  2010        59.331373
# 11  Africa  2011        59.998039
# 12  Africa  2012        60.701961
# 13  Africa  2013        61.309804
# 14  Africa  2014        61.911765
# 15  Africa  2015        62.466667
# 16    Asia  2000        66.648148
# 17    Asia  2001        67.048148
# 18    Asia  2002        67.440741
# 19    Asia  2003        67.833333

# %%
plt.figure(figsize=(12, 6))
for region in df_grouped['Region'].unique():
    region_data = df_grouped[df_grouped['Region'] == region]
    plt.plot(region_data['Year'], region_data['Life_expectancy'], label=region)

plt.xlabel('Year')
plt.ylabel('Mean Life Expectancy')
plt.title('Mean Life Expectancy by Region over Time')
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()
